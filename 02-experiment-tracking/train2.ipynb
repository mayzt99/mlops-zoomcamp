# %%
import os
import pickle
import click
import mlflow
import numpy

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_error

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("random-forest-train")
# Out:
# <Experiment: artifact_location='/workspaces/mlops-zoomcamp/02-experiment-tracking/mlruns/2', creation_time=1748272895662, experiment_id='2', last_update_time=1748272895662, lifecycle_stage='active', name='random-forest-train', tags={}>

# %%
def load_pickle(filename: str):
    with open(filename, "rb") as f_in:
        return pickle.load(f_in)

# %%
def run_train():

    mlflow.sklearn.autolog()

    X_train, y_train = load_pickle("D:/Git/mlops-zoomcamp/mlops-zoomcamp/02-experiment-tracking/output/train.pkl")
    X_val, y_val = load_pickle("D:/Git/mlops-zoomcamp/mlops-zoomcamp/02-experiment-tracking/output/val.pkl")

    with mlflow.start_run():

        rf = RandomForestRegressor(max_depth=10, random_state=0)
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_val)

        rmse = root_mean_squared_error(y_val, y_pred)

# %%
run_train()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 run_train()
#
# Cell In[4], line 5, in run_train()
#       1 def run_train():
#       3     mlflow.sklearn.autolog()
# ----> 5     X_train, y_train = load_pickle("D:/Git/mlops-zoomcamp/mlops-zoomcamp/02-experiment-tracking/output/train.pkl")
#       6     X_val, y_val = load_pickle("D:/Git/mlops-zoomcamp/mlops-zoomcamp/02-experiment-tracking/output/val.pkl")
#       8     with mlflow.start_run():
#
# Cell In[3], line 3, in load_pickle(filename)
#       1 def load_pickle(filename: str):
#       2     with open(filename, "rb") as f_in:
# ----> 3         return pickle.load(f_in)
#
# ModuleNotFoundError: No module named 'numpy._core'

# %%
pip uninstall numpy
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
